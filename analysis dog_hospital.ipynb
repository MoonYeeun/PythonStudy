# %%
import numpy as np
import pandas as pd

# %%
guro_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 구로구 동물병원 현황.csv',encoding='utf-8')
guro_hospital.head()
# Out:
#      시군구코드      신고일자       업소명  영업상태코드 영업상태  \
# 0  3160000  20070608    푸른동물병원       0   정상
# 1  3160000  20060421    수 동물병원       2   폐업
# 2  3160000  20060822  캐슬동물종합병원       2   폐업
# 3  3160000  20060127  캐슬동물종합병원       2   폐업
# 4  3160000  20040930  명24시동물병원       2   폐업
#
#                              사업장소재지(지번)  휴업시작일자  휴업종료일자        폐업일자  재개업일자  \
# 0              서울특별시 구로구 구로동 722번지 4호       NaN     NaN         NaN    NaN
# 1             서울특별시 구로구 구로동 516번지 14호       NaN     NaN  20101013.0    NaN
# 2   서울특별시 구로구 고척동 333번지 하이리빙(아)상가 103호      NaN     NaN  20170706.0    NaN
# 3  서울특별시 구로구 고척동 333번지 하이리빙아파트 상가 103호      NaN     NaN  20060818.0    NaN
# 4   서울특별시 구로구 고척동 329번지 청솔우성(아) 1층107호      NaN     NaN  20050607.0    NaN
#
#    ...       전화번호  면적(㎡)      건물용도  건물구조  지하층  지상층  건물도시계획  건물주변환경  신고면허세종호  \
# 0  ...   861-0075  54.52  2종근린생활시설   NaN  0.0  1.0     NaN     NaN      NaN
# 1  ...   859-7582  43.80       NaN   NaN  0.0  0.0     NaN     NaN      NaN
# ...

# %%
guro_hospital = guro_hospital[guro_hospital['영업상태']=='정상']
guro_hospital.head()
# Out:
#       시군구코드      신고일자     업소명  영업상태코드 영업상태  \
# 0   3160000  20070608  푸른동물병원       0   정상
# 6   3160000  19931220  사랑동물병원       0   정상
# 16  3160000  20151203  마음동물병원       0   정상
# 27  3160000  20121211  벨라동물병원       0   정상
# 28  3160000  20160229  허브동물병원       0   정상
#
#                                사업장소재지(지번)  휴업시작일자  휴업종료일자  폐업일자  재개업일자  ...  \
# 0                서울특별시 구로구 구로동 722번지 4호       NaN     NaN   NaN    NaN  ...
# 6                서울특별시 구로구 구로동 152번지 6호       NaN     NaN   NaN    NaN  ...
# 16               서울특별시 구로구 궁동 286번지 동광빌라      NaN     NaN   NaN    NaN  ...
# 27          서울특별시 구로구 구로동 501번지 12호 진명빌딩      NaN     NaN   NaN    NaN  ...
# 28  서울특별시 구로구 구로동 650번지 4호 SK허브수 B동 205호      NaN     NaN   NaN    NaN  ...
#
#           전화번호  면적(㎡)      건물용도       건물구조  지하층  지상층  건물도시계획  건물주변환경  신고면허세종호  \
# 0     861-0075  54.52  2종근린생활시설        NaN  0.0  1.0     NaN     NaN      NaN
# 6     851-1368  24.50       NaN        NaN  0.0  0.0     NaN     NaN      NaN
# ...

# %%
guro_hospital = guro_hospital[['신고일자','업소명','사업장소재지(지번)','전화번호']]

# %%
guro_hospital = guro_hospital.reset_index(drop = True)
guro_hospital
# Out:
#         신고일자               업소명  \
# 0   20070608            푸른동물병원
# 1   19931220            사랑동물병원
# 2   20151203            마음동물병원
# 3   20121211            벨라동물병원
# 4   20160229            허브동물병원
# 5   20010522        케이나인종합동물병원
# 6   20030121           신도림동물병원
# 7   20140303           안정택동물병원
# 8   20180411            드림동물병원
# 9   20110607   아이러브펫동물병원(신도림점)
# 10  20100317          구로종합동물병원
# 11  20040410          굿모닝 동물병원
# 12  19981118          금강종합동물병원
# 13  20041124          한샘종합동물병원
# 14  20040316            해피동물병원
# 15  19991209  24시 지구촌 동물메디컬 센터
# 16  19990906           라라동물의료원
# 17  19831010            오류동물병원
# 18  19930319            개명동물병원
# 19  20110406          캥거루 동물병원
# 20  19990128            개봉동물병원
# 21  20140811      24시 명동물메디컬센터
#
#                                           사업장소재지(지번)        전화번호
# 0                           서울특별시 구로구 구로동 722번지 4호      861-0075
# 1                           서울특별시 구로구 구로동 152번지 6호      851-1368
# ...

# %%
guro_hospital['사업장소재지(구)'] = '구로구'
guro_hospital = guro_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
guro_hospital
# Out:
#         신고일자               업소명 사업장소재지(구)  \
# 0   20070608            푸른동물병원       구로구
# 1   19931220            사랑동물병원       구로구
# 2   20151203            마음동물병원       구로구
# 3   20121211            벨라동물병원       구로구
# 4   20160229            허브동물병원       구로구
# 5   20010522        케이나인종합동물병원       구로구
# 6   20030121           신도림동물병원       구로구
# 7   20140303           안정택동물병원       구로구
# 8   20180411            드림동물병원       구로구
# 9   20110607   아이러브펫동물병원(신도림점)       구로구
# 10  20100317          구로종합동물병원       구로구
# 11  20040410          굿모닝 동물병원       구로구
# 12  19981118          금강종합동물병원       구로구
# 13  20041124          한샘종합동물병원       구로구
# 14  20040316            해피동물병원       구로구
# 15  19991209  24시 지구촌 동물메디컬 센터       구로구
# 16  19990906           라라동물의료원       구로구
# 17  19831010            오류동물병원       구로구
# 18  19930319            개명동물병원       구로구
# 19  20110406          캥거루 동물병원       구로구
# 20  19990128            개봉동물병원       구로구
# 21  20140811      24시 명동물메디컬센터       구로구
#
# ...

# %%
gangnam_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 강남구 동물병원 현황.csv',encoding='utf-8')
gangnam_hospital.head()
# Out:
#      시군구코드      신고일자           업소명  영업상태코드 영업상태  \
# 0  3220000  20050225       퍼피즌동물병원       0   정상
# 1  3220000  20040923   윤신근박사애견종합병원       2   폐업
# 2  3220000  20041105  쿨 펫 동물병원 강남점       2   폐업
# 3  3220000  20050920       우리들동물병원       2   폐업
# 4  3220000  20050921      청담우리동물병원       2   폐업
#
#                                사업장소재지(지번)  휴업시작일자  휴업종료일자        폐업일자  재개업일자  \
# 0         서울특별시 강남구 삼성동 35번지 32호 대영빌딩 1층      NaN     NaN         NaN    NaN
# 1            서울특별시 강남구 대치동 1023번지 7   호       NaN     NaN  20070611.0    NaN
# 2           서울특별시 강남구 대치동 937번지 롯데백화점 1층      NaN     NaN  20041231.0    NaN
# 3  서울특별시 강남구 압구정동 369번지 1   호 현대2상가 109호      NaN     NaN  20060110.0    NaN
# 4           서울특별시 강남구 삼성동 52번지 송전빌딩 108호      NaN     NaN  20140124.0    NaN
#
#    ...          전화번호  면적(㎡) 건물용도  건물구조  지하층  지상층  건물도시계획  건물주변환경 신고면허세종호  \
# 0  ...   02-541-2651    0.0  NaN   NaN  0.0  0.0     NaN     NaN     NaN
# ...

# %%
gangnam_hospital = gangnam_hospital[gangnam_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
gangnam_hospital = gangnam_hospital.reset_index(drop = True)
gangnam_hospital
# Out:
#         신고일자            업소명  \
# 0   20050225        퍼피즌동물병원
# 1   20121026    와이즈24시 동물병원
# 2   20120801        츄츄 동물병원
# 3   20140218       대치성심동물병원
# 4   20111101        스마트동물병원
# 5   19931101       삼성종합동물병원
# 6   20100917         역삼동물병원
# 7   20050414         논현동물병원
# 8   20100629         충현동물병원
# 9   20150623         선릉동물병원
# 10  20181210    자곡퍼스트동물의료센터
# 11  20030719        서경석동물병원
# 12  20140829         수정동물병원
# 13  20130605         다정동물병원
# 14  20180601         혜민동물병원
# 15  20160902        센트럴동물병원
# 16  20141226     이비치 동물치과병원
# 17  20150114       도곡종합동물병원
# 18  20150217        힐스타동물병원
# 19  20160603    청담눈초롱안과동물병원
# 20  20121224       래이동물의료센터
# 21  20121115         백산동물병원
# 22  20161216      닥터그레이동물병원
# 23  20130513  24시 청담우리 동물병원
# 24  20090814         예은동물병원
# 25  20170109        대치수동물병원
# 26  20150225       강남다온동물병원
# 27  20160913        압구정동물병원
# 28  20151103        굿모닝동물병원
# 29  20160902         수서동물병원
# ..       ...            ...
# 47  20100310         개포동물병원
# ...

# %%
gangnam_hospital['사업장소재지(구)'] = '강남구'
gangnam_hospital = gangnam_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
gangnam_hospital
# Out:
#         신고일자            업소명 사업장소재지(구)  \
# 0   20050225        퍼피즌동물병원       강남구
# 1   20121026    와이즈24시 동물병원       강남구
# 2   20120801        츄츄 동물병원       강남구
# 3   20140218       대치성심동물병원       강남구
# 4   20111101        스마트동물병원       강남구
# 5   19931101       삼성종합동물병원       강남구
# 6   20100917         역삼동물병원       강남구
# 7   20050414         논현동물병원       강남구
# 8   20100629         충현동물병원       강남구
# 9   20150623         선릉동물병원       강남구
# 10  20181210    자곡퍼스트동물의료센터       강남구
# 11  20030719        서경석동물병원       강남구
# 12  20140829         수정동물병원       강남구
# 13  20130605         다정동물병원       강남구
# 14  20180601         혜민동물병원       강남구
# 15  20160902        센트럴동물병원       강남구
# 16  20141226     이비치 동물치과병원       강남구
# 17  20150114       도곡종합동물병원       강남구
# 18  20150217        힐스타동물병원       강남구
# 19  20160603    청담눈초롱안과동물병원       강남구
# 20  20121224       래이동물의료센터       강남구
# 21  20121115         백산동물병원       강남구
# 22  20161216      닥터그레이동물병원       강남구
# ...

# %%
gangdong_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 강동구 동물병원 현황.csv',encoding='utf-8')
gangdong_hospital = gangdong_hospital[gangdong_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
gangdong_hospital = gangdong_hospital.reset_index(drop = True)
gangdong_hospital
# Out:
#         신고일자               업소명                                     사업장소재지(지번)  \
# 0   20150630     스마트동물병원 강동암사점
# 1   19990629           길종합동물병원                           서울특별시 강동구 길동 151번지
# 2   20030607            해태동물병원
# 3   20030307            CH동물병원              서울특별시 강동구 천호동 233번지 145호 19통 4반
# 4   20030607            강동동물병원                        서울특별시 강동구 길동 336번지 4호
# 5   20000531            가나동물병원                서울특별시 강동구 암사동 451번지 12호 5통 8반
# 6   20140526           내품에동물병원
# 7   20080812           늘사랑동물병원
# 8   20030530            두루동물병원
# 9   20130508         미드미동물의료센터                  서울특별시 강동구 명일동 345번지 20호 연우빌딩
# 10  20030607            둔촌동물병원
# 11  20021030         사랑이있는동물병원                                서울특별시 강동구 명일동
# 12  20110407           비타민동물병원
# 13  20130308             석동물병원
# 14  20100430            성내동물병원
# 15  20071012            시온동물병원
# 16  19910619            암사동물병원
# 17  20050811             정동물병원
# 18  20071001           펫클럽동물병원
# ...

# %%
gangdong_hospital['사업장소재지(구)'] = '강동구'
gangdong_hospital = gangdong_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
gangdong_hospital
# Out:
#         신고일자               업소명 사업장소재지(구)  \
# 0   20150630     스마트동물병원 강동암사점       강동구
# 1   19990629           길종합동물병원       강동구
# 2   20030607            해태동물병원       강동구
# 3   20030307            CH동물병원       강동구
# 4   20030607            강동동물병원       강동구
# 5   20000531            가나동물병원       강동구
# 6   20140526           내품에동물병원       강동구
# 7   20080812           늘사랑동물병원       강동구
# 8   20030530            두루동물병원       강동구
# 9   20130508         미드미동물의료센터       강동구
# 10  20030607            둔촌동물병원       강동구
# 11  20021030         사랑이있는동물병원       강동구
# 12  20110407           비타민동물병원       강동구
# 13  20130308             석동물병원       강동구
# 14  20100430            성내동물병원       강동구
# 15  20071012            시온동물병원       강동구
# 16  19910619            암사동물병원       강동구
# 17  20050811             정동물병원       강동구
# 18  20071001           펫클럽동물병원       강동구
# 19  19990126           피카소동물병원       강동구
# 20  20130104            한나동물병원       강동구
# 21  20150602        고덕24시 동물병원       강동구
# ...

# %%
gangbook_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 강북구 동물병원 현황.csv',encoding='utf-8')
gangbook_hospital = gangbook_hospital[gangbook_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
gangbook_hospital = gangbook_hospital.reset_index(drop = True)
gangbook_hospital
# Out:
#         신고일자                업소명  \
# 0   20171211           사랑의 동물병원
# 1   20030718             위즈동물병원
# 2   20030407             대형동물병원
# 3   20030626             창문동물병원
# 4   20190424           아이사랑동물병원
# 5   20170605  24시 수유 바른펫 동물의료센터
# 6   19970818            동물병원 위드
# 7   19950906             중앙동물병원
# 8   20150605             H 동물병원
# 9   19990107             사랑동물병원
# 10  20150818            초이스동물병원
# 11  20071023             삼성동물병원
# 12  20090925             호 동물병원
# 13  20100917             쿠키동물병원
# 14  20020619      애니케어 동물병원 수유점
# 15  19920818             삼양동물병원
# 16  20041101         동물을사랑하는사람들
# 17  20041208             강북동물병원
# 18  20090707           보노보노동물병원
# 19  20020411           현대종합동물병원
# 20  20021015             솔샘동물병원
# 21  20130222             봉식동물병원
# 22  20140206           스마트 동물병원
# 23  20190130      24시루시드동물메디컬센터
#
#                                         사업장소재지(지번)         전화번호
# 0   서울특별시 강북구 미아동 1353번지 5호 에스케이북한산시티 상가동 2동 209호   02-983-8575
# ...

# %%
gangbook_hospital['사업장소재지(구)'] = '강북구'
gangbook_hospital = gangbook_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
gangbook_hospital
# Out:
#         신고일자                업소명 사업장소재지(구)  \
# 0   20171211           사랑의 동물병원       강북구
# 1   20030718             위즈동물병원       강북구
# 2   20030407             대형동물병원       강북구
# 3   20030626             창문동물병원       강북구
# 4   20190424           아이사랑동물병원       강북구
# 5   20170605  24시 수유 바른펫 동물의료센터       강북구
# 6   19970818            동물병원 위드       강북구
# 7   19950906             중앙동물병원       강북구
# 8   20150605             H 동물병원       강북구
# 9   19990107             사랑동물병원       강북구
# 10  20150818            초이스동물병원       강북구
# 11  20071023             삼성동물병원       강북구
# 12  20090925             호 동물병원       강북구
# 13  20100917             쿠키동물병원       강북구
# 14  20020619      애니케어 동물병원 수유점       강북구
# 15  19920818             삼양동물병원       강북구
# 16  20041101         동물을사랑하는사람들       강북구
# 17  20041208             강북동물병원       강북구
# 18  20090707           보노보노동물병원       강북구
# 19  20020411           현대종합동물병원       강북구
# 20  20021015             솔샘동물병원       강북구
# ...

# %%
gangseo_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 강서구 동물병원 현황.csv',encoding='utf-8')
gangseo_hospital = gangseo_hospital[gangseo_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
gangseo_hospital = gangseo_hospital.reset_index(drop = True)
gangseo_hospital
# Out:
#         신고일자             업소명                                      사업장소재지(지번)  \
# 0   20021205          우장동물병원  서울특별시 강서구 화곡동 904번지 8통 8반 목동신시가지아파트 405동 805호
# 1   20040218          하나동물병원                       서울특별시 강서구 방화동 53번지 273호
# 2   20130327         세명 동물병원           서울특별시 강서구 화곡동 134번지 8통 3반 공원아파트 507호
# 3   19950527          시온동물병원                       서울특별시 강서구 화곡동 46번지 236호
# 4   20140325         한마음동물병원          서울특별시 강서구 화곡동 27통 5반 동양아파트 108동 2406호
# 5   20130103      24시 안박동물병원                서울특별시 강서구 등촌동 628번지 13호  101-1호
# 6   20100816         쿨펫 동물병원   서울특별시 강서구 가양동 720번지 31통 10반 주공아파트 615동 1105호
# 7   20141218      강서YD동물의료센터                        서울특별시 강서구 등촌동 658번지 4호
# 8   20100512          오즈동물병원                      서울특별시 강서구 내발산동 722번지 15호
# 9   20021205        염창제일동물병원                       서울특별시 강서구 염창동 244번지 26호
# 10  20021205         고득영동물병원                  서울특별시 강서구 화곡동 861번지 8호 9통 2반
# ...

# %%
gangseo_hospital['사업장소재지(구)'] = '강서구'
gangseo_hospital = gangseo_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
gangseo_hospital
# Out:
#         신고일자             업소명 사업장소재지(구)  \
# 0   20021205          우장동물병원       강서구
# 1   20040218          하나동물병원       강서구
# 2   20130327         세명 동물병원       강서구
# 3   19950527          시온동물병원       강서구
# 4   20140325         한마음동물병원       강서구
# 5   20130103      24시 안박동물병원       강서구
# 6   20100816         쿨펫 동물병원       강서구
# 7   20141218      강서YD동물의료센터       강서구
# 8   20100512          오즈동물병원       강서구
# 9   20021205        염창제일동물병원       강서구
# 10  20021205         고득영동물병원       강서구
# 11  20021205          강서동물병원       강서구
# 12  20080604          대한동물병원       강서구
# 13  20040225  24시아프리카동물메디컬센터       강서구
# 14  20050426          와우동물병원       강서구
# 15  20050907      도그플러스 동물병원       강서구
# 16  20051220        호서동물의료센터       강서구
# 17  20110118        가양쿨펫동물병원       강서구
# 18  20110607         스마일동물병원       강서구
# 19  20150804       송정동물메디컬센터       강서구
# 20  20021213     서울플러스종합동물병원       강서구
# 21  20160617        고려종합동물병원       강서구
# 22  20160607     우리아이동물메디컬센터       강서구
# ...

# %%
gwanak_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 관악구 동물병원 현황.csv',encoding='utf-8')
gwanak_hospital = gwanak_hospital[gwanak_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
gwanak_hospital = gwanak_hospital.reset_index(drop = True)
gwanak_hospital
# Out:
#         신고일자               업소명                         사업장소재지(지번)  \
# 0   20070601          서울허브동물병원    서울특별시 관악구 봉천동 870번지 13호 신원메트로빌
# 1   20040209           행복한동물병원          서울특별시 관악구 봉천동 464번지 38호
# 2   20070601          로잔동물의료센터    서울특별시 관악구 봉천동 40번지 29호 수안빌딩 1층
# 3   20040830           세계로동물병원           서울특별시 관악구 신림동 526번지 9호
# 4   20110701          관악동물종합병원          서울특별시 관악구 봉천동 1665번지 4호
# 5   19880527           보라매동물병원        서울특별시 관악구 봉천동 971번지 14호 1층
# 6   19910430            형제동물병원          서울특별시 관악구 봉천동 923번지 23호
# 7   20190610           스누피동물병원     서울특별시 관악구 신림동 1484번지 6호  101호
# 8   20030703         러브펫종합동물병원           서울특별시 관악구 신림동 564번지 3호
# 9   20030319          신림종합동물병원          서울특별시 관악구 신림동 395번지 53호
# 10  20040212           늘푸른동물병원        서울특별시 관악구 신림동 727번지 21호 1층
# 11  19950621            DS동물병원       서울특별시 관악구 신림동 1668번지 14호 1층
# 12  20020328            양지동물병원        서울특별시 관악구 봉천동 961번지 15호 1층
# ...

# %%
gwanak_hospital['사업장소재지(구)'] = '관악구'
gwanak_hospital = gwanak_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
gwanak_hospital
# Out:
#         신고일자               업소명 사업장소재지(구)                         사업장소재지(지번)  \
# 0   20070601          서울허브동물병원       관악구    서울특별시 관악구 봉천동 870번지 13호 신원메트로빌
# 1   20040209           행복한동물병원       관악구          서울특별시 관악구 봉천동 464번지 38호
# 2   20070601          로잔동물의료센터       관악구    서울특별시 관악구 봉천동 40번지 29호 수안빌딩 1층
# 3   20040830           세계로동물병원       관악구           서울특별시 관악구 신림동 526번지 9호
# 4   20110701          관악동물종합병원       관악구          서울특별시 관악구 봉천동 1665번지 4호
# 5   19880527           보라매동물병원       관악구        서울특별시 관악구 봉천동 971번지 14호 1층
# 6   19910430            형제동물병원       관악구          서울특별시 관악구 봉천동 923번지 23호
# 7   20190610           스누피동물병원       관악구     서울특별시 관악구 신림동 1484번지 6호  101호
# 8   20030703         러브펫종합동물병원       관악구           서울특별시 관악구 신림동 564번지 3호
# 9   20030319          신림종합동물병원       관악구          서울특별시 관악구 신림동 395번지 53호
# 10  20040212           늘푸른동물병원       관악구        서울특별시 관악구 신림동 727번지 21호 1층
# 11  19950621            DS동물병원       관악구       서울특별시 관악구 신림동 1668번지 14호 1층
# ...

# %%
gwangjin_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 광진구 동물병원 현황.csv',encoding='utf-8')
gwangjin_hospital = gwangjin_hospital[gwangjin_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
gwangjin_hospital = gwangjin_hospital.reset_index(drop = True)
gwangjin_hospital
# Out:
#         신고일자            업소명                            사업장소재지(지번)  \
# 0   20120612         다온동물병원             서울특별시 광진구 중곡동 193번지 29호
# 1   20160909        해맑은동물병원             서울특별시 광진구 자양동 662번지 13호
# 2   20051005         나래동물병원                서울특별시 광진구 군자동 1번지 2호
# 3   20110602   서울어린이대공원동물병원                서울특별시 광진구 능동 18번지 0호
# 4   20160404  로얄 도그앤캣 메디컬센터              서울특별시 광진구 자양동 550번지 1호
# 5   20161012       광장동물의료센터             서울특별시 광진구 광장동 326번지 16호
# 6   20171019         우리동물병원
# 7   20170328         쿨펫동물병원
# 8   20170925         연두동물병원
# 9   20170125        파라곤동물병원
# 10  20170731         반디동물병원
# 11  20021226         중곡동물병원             서울특별시 광진구 중곡동 241번지 34호
# 12  20141210         서울동물병원              서울특별시 광진구 중곡동 119번지 7호
# 13  19990122        동서울동물병원         서울특별시 광진구 광장동 517번지 5호 삼익아파트
# 14  20050602       이다종합동물병원            서울특별시 광진구 자양동 553번지 280호
# 15  20130627         자양동물병원             서울특별시 광진구 자양동 606번지 27호
# ...

# %%
gwangjin_hospital['사업장소재지(구)'] = '광진구'
gwangjin_hospital = gwangjin_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
gwangjin_hospital
# Out:
#         신고일자            업소명 사업장소재지(구)                            사업장소재지(지번)  \
# 0   20120612         다온동물병원       광진구             서울특별시 광진구 중곡동 193번지 29호
# 1   20160909        해맑은동물병원       광진구             서울특별시 광진구 자양동 662번지 13호
# 2   20051005         나래동물병원       광진구                서울특별시 광진구 군자동 1번지 2호
# 3   20110602   서울어린이대공원동물병원       광진구                서울특별시 광진구 능동 18번지 0호
# 4   20160404  로얄 도그앤캣 메디컬센터       광진구              서울특별시 광진구 자양동 550번지 1호
# 5   20161012       광장동물의료센터       광진구             서울특별시 광진구 광장동 326번지 16호
# 6   20171019         우리동물병원       광진구
# 7   20170328         쿨펫동물병원       광진구
# 8   20170925         연두동물병원       광진구
# 9   20170125        파라곤동물병원       광진구
# 10  20170731         반디동물병원       광진구
# 11  20021226         중곡동물병원       광진구             서울특별시 광진구 중곡동 241번지 34호
# 12  20141210         서울동물병원       광진구              서울특별시 광진구 중곡동 119번지 7호
# 13  19990122        동서울동물병원       광진구         서울특별시 광진구 광장동 517번지 5호 삼익아파트
# ...

# %%
geumcheon_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 금천구 동물병원 현황.csv',encoding='utf-8')
geumcheon_hospital = geumcheon_hospital[geumcheon_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
geumcheon_hospital = geumcheon_hospital.reset_index(drop = True)
geumcheon_hospital
# Out:
#         신고일자             업소명                       사업장소재지(지번)         전화번호
# 0   20071109       도그플러스동물병원         서울특별시 금천구 독산동 291번지 7호       809-0075
# 1   20070405          금천동물병원       서울특별시 금천구 독산동 378번지 397호       894-8085
# 2   20070405         조정연동물병원        서울특별시 금천구 시흥동 838번지 33호       806-8355
# 3   20070405          그린동물병원        서울특별시 금천구 독산동 193번지 31호       856-4113
# 4   20030711        제일종합동물병원        서울특별시 금천구 시흥동 837번지 37호       894-3030
# 5   20131127       우리동물메디컬센터         서울특별시 금천구 독산동 950번지 3호       853-7582
# 6   20050525      은행나무종합동물병원         서울특별시 금천구 시흥동 909번지 5호       804-0975
# 7   20120622          쿨펫동물병원  서울특별시 금천구 독산동 102번지 12호 9통 9반            NaN
# 8   20070405         파랑새동물병원       서울특별시 금천구 독산동 1077번지 31호       805-2825
# 9   20081017          노아동물병원         서울특별시 금천구 시흥동 262번지 6호       805-4758
# 10  20160608         독산온동물병원       서울특별시 금천구 독산동 1023번지 14호            NaN
# ...

# %%
geumcheon_hospital['사업장소재지(구)'] = '금천구'
geumcheon_hospital = geumcheon_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
geumcheon_hospital
# Out:
#         신고일자             업소명 사업장소재지(구)                       사업장소재지(지번)  \
# 0   20071109       도그플러스동물병원       금천구         서울특별시 금천구 독산동 291번지 7호
# 1   20070405          금천동물병원       금천구       서울특별시 금천구 독산동 378번지 397호
# 2   20070405         조정연동물병원       금천구        서울특별시 금천구 시흥동 838번지 33호
# 3   20070405          그린동물병원       금천구        서울특별시 금천구 독산동 193번지 31호
# 4   20030711        제일종합동물병원       금천구        서울특별시 금천구 시흥동 837번지 37호
# 5   20131127       우리동물메디컬센터       금천구         서울특별시 금천구 독산동 950번지 3호
# 6   20050525      은행나무종합동물병원       금천구         서울특별시 금천구 시흥동 909번지 5호
# 7   20120622          쿨펫동물병원       금천구  서울특별시 금천구 독산동 102번지 12호 9통 9반
# 8   20070405         파랑새동물병원       금천구       서울특별시 금천구 독산동 1077번지 31호
# 9   20081017          노아동물병원       금천구         서울특별시 금천구 시흥동 262번지 6호
# 10  20160608         독산온동물병원       금천구       서울특별시 금천구 독산동 1023번지 14호
# 11  20160630          조아동물병원       금천구        서울특별시 금천구 독산동 1102번지 5호
# ...

# %%
nowon_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 노원구 동물병원 현황.csv',encoding='utf-8')
nowon_hospital = nowon_hospital[nowon_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
nowon_hospital = nowon_hospital.reset_index(drop = True)
nowon_hospital
# Out:
#         신고일자               업소명                                     사업장소재지(지번)  \
# 0   19980711           25시동물병원               서울특별시 노원구 중계동 363번지 대림벽산상가 102호
# 1   20010523            미래동물병원            서울특별시 노원구 공릉동 94번지 6호 13통 7반  301호
# 2   20050729            수 동물병원          서울특별시 노원구 상계동 1265번지 동방미주(아)109-1001
# 3   20130115            엔젤동물병원                       서울특별시 노원구 공릉동 362번지 3호
# 4   20000407            고려동물병원               서울특별시 노원구 상계동 79번지 145호 44통 4반
# 5   20150522         메인동물메디컬센터                      서울특별시 노원구 공릉동 576번지 23호
# 6   20160211           한국동물암센터                       서울특별시 노원구 상계동 371번지 2호
# 7   20100716          아란종합동물병원                서울특별시 노원구 월계동 3번지 94호 드림빌 201호
# 8   20010613         우리들동물종합병원              서울특별시 노원구 중계동 512번지 시영2단지상가 116호
# 9   20060407           수락 동물병원             서울특별시 노원구 상계동 11번지 410호 태성빌라 202호
# 10  20060127           LK 동물병원          서울특별시 노원구 중계동 360번지 2호 청구3차 상가동 133호
# ...

# %%
nowon_hospital['사업장소재지(구)'] = '노원구'
nowon_hospital = nowon_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 동작구 동물병원 현황.csv',encoding='utf-8')
dongjak_hospital = dongjak_hospital[dongjak_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
dongjak_hospital = dongjak_hospital.reset_index(drop = True)
dongjak_hospital
# Out:
#         신고일자                 업소명                         사업장소재지(지번)  \
# 0   20120118              나무동물병원           서울특별시 동작구 흑석동 335번지 1호
# 1   20120620           흑석24시동물병원             서울특별시 동작구 흑석동 6번지 5호
# 2   20120214            우리아이동물병원    서울특별시 동작구 상도동 34번지 18호 1층 및 2층
# 3   20100429          세인트필립 동물병원     서울특별시 동작구 사당동 1047번지 49호 102호
# 4   19990125              사당동물병원         서울특별시 동작구 사당동 1047번지 44호
# 5   20030225              동물은내친구         서울특별시 동작구 사당동 321번지 114호
# 6   20130311            상도힐링동물병원           서울특별시 동작구 상도동 486번지 7호
# 7   20080115             피닉스동물병원           서울특별시 동작구 대방동 395번지 4호
# 8   20070522              다나동물병원  서울특별시 동작구 사당동 1019번지 54호 오사빌딩 1층
# 9   20010807            하나사랑동물병원          서울특별시 동작구 상도동 366번지 24호
# 10  19760701              중앙동물병원          서울특별시 동작구 흑석동 8번지 32호 1층
# 11  20161205             캐나다동물병원       서울특별시 동작구 상도동 348번지 148호 1층
# 12  19920527              모범동물병원          서울특별시 동작구 사당동 265번지 12호
# ...

# %%
dongjak_hospital['사업장소재지(구)'] = '동작구'
dongjak_hospital = dongjak_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
dongjak_hospital
# Out:
#         신고일자                 업소명 사업장소재지(구)                         사업장소재지(지번)  \
# 0   20120118              나무동물병원       동작구           서울특별시 동작구 흑석동 335번지 1호
# 1   20120620           흑석24시동물병원       동작구             서울특별시 동작구 흑석동 6번지 5호
# 2   20120214            우리아이동물병원       동작구    서울특별시 동작구 상도동 34번지 18호 1층 및 2층
# 3   20100429          세인트필립 동물병원       동작구     서울특별시 동작구 사당동 1047번지 49호 102호
# 4   19990125              사당동물병원       동작구         서울특별시 동작구 사당동 1047번지 44호
# 5   20030225              동물은내친구       동작구         서울특별시 동작구 사당동 321번지 114호
# 6   20130311            상도힐링동물병원       동작구           서울특별시 동작구 상도동 486번지 7호
# 7   20080115             피닉스동물병원       동작구           서울특별시 동작구 대방동 395번지 4호
# 8   20070522              다나동물병원       동작구  서울특별시 동작구 사당동 1019번지 54호 오사빌딩 1층
# 9   20010807            하나사랑동물병원       동작구          서울특별시 동작구 상도동 366번지 24호
# 10  19760701              중앙동물병원       동작구          서울특별시 동작구 흑석동 8번지 32호 1층
# ...

# %%
mapo_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 마포구 동물병원 현황.csv',encoding='utf-8')
mapo_hospital = mapo_hospital[mapo_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
mapo_hospital = mapo_hospital.reset_index(drop = True)
mapo_hospital
# Out:
#         신고일자                  업소명                                 사업장소재지(지번)  \
# 0   20040604               마리동물병원                  서울특별시 마포구 동교동 174번지 20호
# 1   19880330               서진동물병원                  서울특별시 마포구 동교동 185번지 22호
# 2   20130315          힐링 24시 동물병원    서울특별시 마포구 신공덕동 172번지 펜트라우스 105동B2-35gh
# 3   19960108               용강동물병원                  서울특별시 마포구 대흥동 337번지 41호
# 4   20171023      서울동물복지지원센터 동물병원
# 5   20150522            우리동생 동물병원
# 6   20130703          공덕 건강한 동물병원         서울특별시 마포구 공덕동 256번지 13호 제일빌딩 108호
# 7   20160121        24시 산들산들 동물병원
# 8   20140707             굿모닝 동물병원                   서울특별시 마포구 염리동 164번지 4호
# 9   19950706             뉴욕종합동물병원                  서울특별시 마포구 서교동 395번지 44호
# 10  20160104           닥터 호오 동물병원                  서울특별시 마포구 용강동 494번지 68호
# 11  20170126             푸른숲 동물병원                     서울특별시 마포구 서교동 5번지 2호
# 12  20120106            박효리군 동물병원                  서울특별시 마포구 망원동 338번지 76호
# ...

# %%
mapo_hospital['사업장소재지(구)'] = '마포구'
mapo_hospital = mapo_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
mapo_hospital
# Out:
#         신고일자                  업소명 사업장소재지(구)  \
# 0   20040604               마리동물병원       마포구
# 1   19880330               서진동물병원       마포구
# 2   20130315          힐링 24시 동물병원       마포구
# 3   19960108               용강동물병원       마포구
# 4   20171023      서울동물복지지원센터 동물병원       마포구
# 5   20150522            우리동생 동물병원       마포구
# 6   20130703          공덕 건강한 동물병원       마포구
# 7   20160121        24시 산들산들 동물병원       마포구
# 8   20140707             굿모닝 동물병원       마포구
# 9   19950706             뉴욕종합동물병원       마포구
# 10  20160104           닥터 호오 동물병원       마포구
# 11  20170126             푸른숲 동물병원       마포구
# 12  20120106            박효리군 동물병원       마포구
# 13  20070822              웰케어동물병원       마포구
# 14  20140711               카라동물병원       마포구
# 15  20121123        캣&덴탈 하이디 동물병원       마포구
# 16  20070314            박창석종합동물병원       마포구
# 17  20141117              예스 동물병원       마포구
# 18  20101129             동물메디컬센터w       마포구
# 19  20140430             동물병원 닥터K       마포구
# ...

# %%
seodaemun_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 서대문구 동물병원 현황.csv',encoding='utf-8')
seodaemun_hospital = seodaemun_hospital[seodaemun_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
seodaemun_hospital = seodaemun_hospital.reset_index(drop = True)
seodaemun_hospital
# Out:
#         신고일자           업소명                              사업장소재지(지번)  \
# 0   20150213        햇살동물병원                 서울특별시 서대문구 북가좌동 487번지
# 1   20040421        우리동물병원                  서울특별시 서대문구 영천동 299번지
# 2   20170519      강앤정 동물병원         서울특별시 서대문구 남가좌동 385번지 DMC파크뷰자이
# 3   20151127       어울림동물병원              서울특별시 서대문구 남가좌동 124번지 1호
# 4   20180426    에이플러스 동물병원           서울특별시 서대문구 연희동 135번지 9호 내풍빌딩
# 5   20050511  마음을 나누는 동물병원  서울특별시 서대문구 북아현동 136번지 21호 e편한세상신촌 4단지
# 6   20111018    가재울봉쥬르동물병원             서울특별시 서대문구 북가좌동 304번지 29호
# 7   19970212       북아현동물병원             서울특별시 서대문구 북아현동 126번지 12호
# 8   20021224        홍제동물병원              서울특별시 서대문구 홍제동 330번지 54호
# 9   19940324        가좌동물병원              서울특별시 서대문구 북가좌동 308번지 1호
# 10  19970110        한솔동물병원               서울특별시 서대문구 홍제동 103번지 6호
# 11  20010628        신영동물병원           서울특별시 서대문구 홍은동 217번지 30호  나호
# 12  20150805       독립문동물병원                  서울특별시 서대문구 냉천동 195번지
# ...

# %%
seodaemun_hospital['사업장소재지(구)'] = '서대문구'
seodaemun_hospital = seodaemun_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
seodaemun_hospital
# Out:
#         신고일자           업소명 사업장소재지(구)                              사업장소재지(지번)  \
# 0   20150213        햇살동물병원      서대문구                 서울특별시 서대문구 북가좌동 487번지
# 1   20040421        우리동물병원      서대문구                  서울특별시 서대문구 영천동 299번지
# 2   20170519      강앤정 동물병원      서대문구         서울특별시 서대문구 남가좌동 385번지 DMC파크뷰자이
# 3   20151127       어울림동물병원      서대문구              서울특별시 서대문구 남가좌동 124번지 1호
# 4   20180426    에이플러스 동물병원      서대문구           서울특별시 서대문구 연희동 135번지 9호 내풍빌딩
# 5   20050511  마음을 나누는 동물병원      서대문구  서울특별시 서대문구 북아현동 136번지 21호 e편한세상신촌 4단지
# 6   20111018    가재울봉쥬르동물병원      서대문구             서울특별시 서대문구 북가좌동 304번지 29호
# 7   19970212       북아현동물병원      서대문구             서울특별시 서대문구 북아현동 126번지 12호
# 8   20021224        홍제동물병원      서대문구              서울특별시 서대문구 홍제동 330번지 54호
# 9   19940324        가좌동물병원      서대문구              서울특별시 서대문구 북가좌동 308번지 1호
# 10  19970110        한솔동물병원      서대문구               서울특별시 서대문구 홍제동 103번지 6호
# ...

# %%
seocho_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 서초구 동물병원 현황.csv',encoding='utf-8')
seocho_hospital = seocho_hospital[seocho_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
seocho_hospital = seocho_hospital.reset_index(drop = True)
seocho_hospital
# Out:
#         신고일자              업소명                                  사업장소재지(지번)  \
# 0   20160725  VIP동물의료센터 서초동작점            서울특별시 서초구 방배동 442번지 3호 대광빌딩 12층
# 1   20081121           리즈동물병원                     서울특별시 서초구 잠원동 49번지 8호
# 2   20051230          다니엘동물병원                   서울특별시 서초구 서초동 1487번지 1호
# 3   20190812    에이비씨(ABC)동물병원     서울특별시 서초구 서초동 1332번지 2호 대한무지개종합상가 103호
# 4   20190718      V+care 동물병원             서울특별시 서초구 반포동 739번지 32호 제이디 빌딩
# 5   20000221          레스펫동물병원                 서울특별시 서초구 양재동 2번지 43호 동리빌딩
# 6   20040414          이상록동물병원        서울특별시 서초구 잠원동 50번지 5호 신사쇼핑센터 102-2호
# 7   20040308           우면동물병원          서울특별시 서초구 우면동 66번지 2호 우면세신상가 201호
# 8   20011217         방배한강동물병원               서울특별시 서초구 방배동 811번지 11호 지상1층
# 9   19980112           서초동물병원                  서울특별시 서초구 서초동 1603번지 66호
# 10  19970117          남서울동물병원                    서울특별시 서초구 방배동 809번지 1호
# 11  20000711          라파엘동물병원                   서울특별시 서초구 반포동 722번지 29호
# ...

# %%
seocho_hospital['사업장소재지(구)'] = '서초구'
seocho_hospital = seocho_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
seongbuk_hospital = seongbuk_hospital.reset_index(drop = True)
seongbuk_hospital
# Out:
#         신고일자              업소명  \
# 0   20000314         나래종합동물병원
# 1   20000331           다나동물병원
# 2   20010412           강북동물병원
# 3   20030130           드림동물병원
# 4   19990106          한사랑동물병원
# 5   20140402         도담도담동물병원
# 6   20030512           길음동물병원
# 7   19980728            큐동물병원
# 8   20161212           포유동물병원
# 9   20070628         비비펫 동물병원
# 10  20150804         넬 동물의료센터
# 11  20140501       카카오 N 동물병원
# 12  20140107          꿈의숲동물병원
# 13  20070813           이솝동물병원
# 14  20161006    스마트동물병원 성북길음점
# 15  20100211          태양 동물병원
# 16  20000801         서울종합동물병원
# 17  20010507           대학동물병원
# 18  20060728           미소동물병원
# 19  20140724  강북 24시 N 동물의료센터
# 20  20100414        쓰담쓰담 동물병원
# 21  20120626           마로동물병원
# 22  20130507           호담동물병원
# 23  20170919           로이동물병원
# 24  20070329           중앙동물병원
# 25  20160224           앙리동물병원
# 26  20180123           보람동물병원
# 27  20050830          행복한동물병원
# 28  20070820          ZOO동물병원
# 29  20081016       24시 애니동물병원
# ...

# %%
seongbuk_hospital['사업장소재지(구)'] = '성북구'
seongbuk_hospital = seongbuk_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
seongbuk_hospital
# Out:
#         신고일자              업소명 사업장소재지(구)  \
# 0   20000314         나래종합동물병원       성북구
# 1   20000331           다나동물병원       성북구
# 2   20010412           강북동물병원       성북구
# 3   20030130           드림동물병원       성북구
# 4   19990106          한사랑동물병원       성북구
# 5   20140402         도담도담동물병원       성북구
# 6   20030512           길음동물병원       성북구
# 7   19980728            큐동물병원       성북구
# 8   20161212           포유동물병원       성북구
# 9   20070628         비비펫 동물병원       성북구
# 10  20150804         넬 동물의료센터       성북구
# 11  20140501       카카오 N 동물병원       성북구
# 12  20140107          꿈의숲동물병원       성북구
# 13  20070813           이솝동물병원       성북구
# 14  20161006    스마트동물병원 성북길음점       성북구
# 15  20100211          태양 동물병원       성북구
# 16  20000801         서울종합동물병원       성북구
# 17  20010507           대학동물병원       성북구
# 18  20060728           미소동물병원       성북구
# 19  20140724  강북 24시 N 동물의료센터       성북구
# 20  20100414        쓰담쓰담 동물병원       성북구
# 21  20120626           마로동물병원       성북구
# ...

# %%
songpa_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 송파구 동물병원 현황.csv',encoding='utf-8')
songpa_hospital = songpa_hospital[songpa_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
songpa_hospital = songpa_hospital.reset_index(drop = True)
songpa_hospital
# Out:
#         신고일자               업소명  \
# 0   20020501           늘푸른동물병원
# 1   19971204            천호동물병원
# 2   19970315         위드펫종합동물병원
# 3   20160629         송파스마일동물병원
# 4   20151202           키다리동물병원
# 5   20020215         동물의왕국동물병원
# 6   20110805           봄빛 동물병원
# 7   20070314         KYH웰빙동물병원
# 8   19990108          가락종합동물병원
# 9   20150612       온마음 동물메디컬센터
# 10  20100830          갤러리아동물병원
# 11  20030121           펫가든동물병원
# 12  20181113         샤인동물메디컬센터
# 13  20110107            연 동물병원
# 14  20040203          에버펫 동물병원
# 15  20041013          송이종합동물병원
# 16  19900808           이재풍동물병원
hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
yangchun_hospital
# Out:
#         신고일자             업소명 사업장소재지(구)  \
# 0   20130716         오라고동물병원       양천구
# 1   20030424        토론토 동물병원       양천구
# 2   20020511        애니케어동물병원       양천구
# 3   20040922       파란종합 동물병원       양천구
# 4   20081021       행복한세상동물병원       양천구
# 5   20090703  쿨펫이마트 목동점 동물병원       양천구
# 6   20091217        가나종합동물병원       양천구
# 7   20070327     리더스24시 동물병원       양천구
# 8   19970320        양천종합동물병원       양천구
# 9   19990625         민병철동물병원       양천구
# 10  20030422         신정 동물병원       양천구
# 11  20020503         필동물종합병원       양천구
# 12  20040117         참사랑동물병원       양천구
# 13  20080723          햇살동물병원       양천구
# 14  20170410   24시 서울 탑 동물병원       양천구
# 15  20170628          두암동물병원       양천구
# 16  20060214         일오삼동물병원       양천구
# 17  20151203         공원옆동물병원       양천구
# 18  20020605       혜인종합 동물병원       양천구
# 19  19971029          이솝동물병원       양천구
# 20  20141201         팜랜드동물병원       양천구
# 21  19900223      강현림 종합동물병원       양천구
# 22  19990309        나우동물종합병원       양천구
# ...

# %%
yeongdeungpo_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 영등포구 동물병원 현황.csv',encoding='utf-8')
yeongdeungpo_hospital = yeongdeungpo_hospital[yeongdeungpo_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
yeongdeungpo_hospital = yeongdeungpo_hospital.reset_index(drop = True)
yeongdeungpo_hospital
# Out:
#         신고일자            업소명                                     사업장소재지(지번)  \
# 0   20020326         한국동물병원                      서울특별시 영등포구 신길동 829번지 1호
# 1   20100623         유석동물병원                        서울특별시 영등포구 신길동 4824번지
# 2   20120223         왈츠동물병원                      서울특별시 영등포구 대림동 776번지 2호
# 3   20100422     온누리 종합동물병원                   서울특별시 영등포구 신길동 214번지 55호 2층
# 4   20121126      도그플러스동물병원                   서울특별시 영등포구 문래동3가 55번지 3호 4층
# 5   19881114         대방동물병원                         서울특별시 영등포구 신길동 628번지
# 6   20000519         참 동물병원                      서울특별시 영등포구 신길동 95번지 39호
# 7   19980819         도림동물병원                     서울특별시 영등포구 신길동 296번지 12호
# 8   20140214        미소로동물병원                       서울특별시 영등포구 영등포동8가 72번지
# 9   20170216       이든동물의료센터                 서울특별시 영등포구 당산동5가 11번지 30호 12층
# 10  20040504         서울동물병원                   서울특별시 영등포구 영등포동7가 64번지 48호
# 11  20070627       디오빌 동물병원      서울특별시 영등포구 당산동5가 11번지 33호 당산디오빌 1층 103-3
# ...

# %%
yeongdeungpo_hospital['사업장소재지(구)'] = '영등포구'
yeongdeungpo_hospital = yeongdeungpo_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
yeongdeungpo_hospital
# Out:
#         신고일자            업소명 사업장소재지(구)  \
# 0   20020326         한국동물병원      영등포구
# 1   20100623         유석동물병원      영등포구
# 2   20120223         왈츠동물병원      영등포구
# 3   20100422     온누리 종합동물병원      영등포구
# 4   20121126      도그플러스동물병원      영등포구
# 5   19881114         대방동물병원      영등포구
# 6   20000519         참 동물병원      영등포구
# 7   19980819         도림동물병원      영등포구
# 8   20140214        미소로동물병원      영등포구
# 9   20170216       이든동물의료센터      영등포구
# 10  20040504         서울동물병원      영등포구
# 11  20070627       디오빌 동물병원      영등포구
# 12  20151016       아프리카동물병원      영등포구
# 13  20160303       경인동물의료센터      영등포구
# 14  20130103        영등포동물병원      영등포구
# 15  20180110         사랑동물병원      영등포구
# 16  20161027         아람동물병원      영등포구
# 17  20071109       Dr.수동물병원      영등포구
# 18  20170207     여의도동물병원대교점      영등포구
# 19  20170207     여의도동물병원은하점      영등포구
# 20  20000218       신풍동물종합병원      영등포구
# 21  20170522       신길 온동물병원      영등포구
# 22  20180622  24시 수 동물메디컬센터      영등포구
# ...

# %%
yongsan_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 용산구 동물병원 현황.csv',encoding='utf-8')
yongsan_hospital = yongsan_hospital[yongsan_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
yongsan_hospital = yongsan_hospital.reset_index(drop = True)
yongsan_hospital
# Out:
#         신고일자                           업소명  \
# 0   20021223                        효창동물병원
# 1   20021230                      원효종합동물병원
# 2   20161021  바다동물병원(Bada Animal Hospital)
# 3   20161215                 24시 시유동물메디컬센터
# 4   20180514                       펫세상동물병원
# 5   20110315                    (주)이상윤동물병원
# 6   20170308                        베이동물병원
# 7   20130506                       동물병원 메이
# 8   20131028                        퍼스동물병원
# 9   20090501                        라온동물병원
# 10  20101029                      아프리카동물병원
# 11  20120102                        달래동물병원
# 12  20120307                        민트동물병원
# 13  20050624                      청화종합동물병원
# 14  20030801                       한사랑동물병원
# 15  20021223                        남산동물병원
# 16  20021227                      열린동물종합병원
# 17  20051104                       펫토이동물병원
# 18  20021223                      21세기동물병원
# 19  20021223                        이수의과의원
# 20  20021227                        한남동물병원
# ...

# %%
yongsan_hospital['사업장소재지(구)'] = '용산구'
yongsan_hospital = yongsan_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
yongsan_hospital
# Out:
#         신고일자                           업소명 사업장소재지(구)  \
# 0   20021223                        효창동물병원       용산구
# 1   20021230                      원효종합동물병원       용산구
# 2   20161021  바다동물병원(Bada Animal Hospital)       용산구
# 3   20161215                 24시 시유동물메디컬센터       용산구
# 4   20180514                       펫세상동물병원       용산구
# 5   20110315                    (주)이상윤동물병원       용산구
# 6   20170308                        베이동물병원       용산구
# 7   20130506                       동물병원 메이       용산구
# 8   20131028                        퍼스동물병원       용산구
# 9   20090501                        라온동물병원       용산구
# 10  20101029                      아프리카동물병원       용산구
# 11  20120102                        달래동물병원       용산구
# 12  20120307                        민트동물병원       용산구
# 13  20050624                      청화종합동물병원       용산구
# 14  20030801                       한사랑동물병원       용산구
# 15  20021223                        남산동물병원       용산구
# 16  20021227                      열린동물종합병원       용산구
# ...

# %%
eunpyeong_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 은평구 동물병원 현황.csv',encoding='utf-8')
eunpyeong_hospital = eunpyeong_hospital[eunpyeong_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
eunpyeong_hospital = eunpyeong_hospital.reset_index(drop = True)
eunpyeong_hospital
# Out:
#         신고일자               업소명  \
# 0   20021224           한마음동물병원
# 1   20010702            더독동물병원
# 2   20040608           메디펫동물병원
# 3   19950623            한얼동물병원
# 4   19960506            녹번동물병원
# 5   19900306            불광동물병원
# 6   20060126            로얄동물병원
# 7   19750125            응암동물병원
# 8   20161025          개와냥이동물병원
# 9   20140521           스머프동물병원
# 10  20050816         한수24시동물병원
# 11  20021203      금쪽같은내새끼 동물병원
# 12  20120704        도그원 동물의료센터
hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
jongno_hospital
# Out:
#        신고일자          업소명 사업장소재지(구)  \
# 0  20060327      올리브동물병원       종로구
# 1  20011211        해동물병원       종로구
# 2  20090708      누리봄동물병원       종로구
# 3  20080306       우리동물병원       종로구
# 4  20160211      광화문동물병원       종로구
# 5  20171116  경희궁 바른 동물병원       종로구
# 6  19990423      월드펫동물병원       종로구
# 7  19950905      대학로동물병원       종로구
# 8  20021025       북악동물병원       종로구
#
#                                     사업장소재지(지번)         전화번호
# 0                     서울특별시 종로구 홍지동 126번지 8호        3917502
# 1                      서울특별시 종로구 창신동 80번지 1호            NaN
# 2                     서울특별시 종로구 내자동 125번지 3호    02-735-7530
# 3                      서울특별시 종로구 숭인동 52번지 8호      3676-1190
# 4                         서울특별시 종로구 효자동 31번지       722-8275
# 5  서울특별시 종로구 홍파동 42번지 13호 경희궁자이 2단지 상가동 2229호           NaN
# 6                      서울특별시 종로구 신영동 1번지 11호       379-7575
# 7      서울특별시 종로구 명륜2가 5번지 99호 1통 3반 방산빌라 402호     3672-8441
# 8          서울특별시 종로구 홍지동 127번지 7호 5통 5반 지층 3호      391-4575

# %%
junggu_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 중구 동물병원 현황.csv',encoding='utf-8')
junggu_hospital = junggu_hospital[junggu_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
junggu_hospital = junggu_hospital.reset_index(drop = True)
junggu_hospital
# Out:
#         신고일자           업소명                         사업장소재지(지번)          전화번호
# 0   20110630        백슬동물병원  서울특별시 중구 만리동2가 288번지 서울역한라비발디센트럴    02-393-7588
# 1   20190327   한국양봉농협 동물병원  서울특별시 중구 신당동 309번지 50호 한국양봉농협 본점   02-2210-2539
# 2   20150204      그녀의 동물병원           서울특별시 중구 신당동 844번지 남산타운   02-2237-7582
# 3   20160211        바른동물병원      서울특별시 중구 황학동 2523번지 황학 아크로타워   02-2232-7975
# 4   20040514       차지우동물병원        서울특별시 중구 신당동 422번지 1호 청화빌딩      2237-7533
# 5   20011226     미래지동물의료센터           서울특별시 중구 신당동 368번지 19호       2233-7574
# 6   20020810        남산동물병원           서울특별시 중구 신당동 844번지 남산타운      2256-8275
# 7   19920212      바우미우동물병원        서울특별시 중구 신당동 336번지 3호 명덕빌딩      2237-3366
# 8   19900925     윤신근박사동물병원               서울특별시 중구 필동2가 53번지       2274-8558
# 9   19950512         황동물병원             서울특별시 중구 묵정동 32번지 1호       2278-0075
# 10  20190513        메종동물병원            서울특별시 중구 신당동 102번지 6호    02-2038-7555
# ...

# %%
junggu_hospital['사업장소재지(구)'] = '중구'
junggu_hospital = junggu_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
junggu_hospital
# Out:
#         신고일자           업소명 사업장소재지(구)                         사업장소재지(지번)  \
# 0   20110630        백슬동물병원        중구  서울특별시 중구 만리동2가 288번지 서울역한라비발디센트럴
# 1   20190327   한국양봉농협 동물병원        중구  서울특별시 중구 신당동 309번지 50호 한국양봉농협 본점
# 2   20150204      그녀의 동물병원        중구           서울특별시 중구 신당동 844번지 남산타운
# 3   20160211        바른동물병원        중구      서울특별시 중구 황학동 2523번지 황학 아크로타워
# 4   20040514       차지우동물병원        중구        서울특별시 중구 신당동 422번지 1호 청화빌딩
# 5   20011226     미래지동물의료센터        중구           서울특별시 중구 신당동 368번지 19호
# 6   20020810        남산동물병원        중구           서울특별시 중구 신당동 844번지 남산타운
# 7   19920212      바우미우동물병원        중구        서울특별시 중구 신당동 336번지 3호 명덕빌딩
# 8   19900925     윤신근박사동물병원        중구               서울특별시 중구 필동2가 53번지
# 9   19950512         황동물병원        중구             서울특별시 중구 묵정동 32번지 1호
# 10  20190513        메종동물병원        중구            서울특별시 중구 신당동 102번지 6호
# 11  19950802        대한동물병원        중구           서울특별시 중구 충무로4가 93번지 1호
# ...

# %%
jungnang_hospital = pd.read_csv('C:/python/DataScience/data/animal/서울시 중랑구 동물병원 현황.csv',encoding='utf-8')
jungnang_hospital = jungnang_hospital[jungnang_hospital['영업상태']=='정상'][['신고일자','업소명','사업장소재지(지번)','전화번호']]
jungnang_hospital = jungnang_hospital.reset_index(drop = True)
jungnang_hospital
# Out:
#         신고일자              업소명                        사업장소재지(지번)          전화번호
# 0   19911130           태능동물병원         서울특별시 중랑구 묵동 175번지 2호 3층       973-1953
# 1   20141107       도그플러스 동물병원      서울특별시 중랑구 신내동 645번지 홈플러스 2층      3421-9075
# 2   20141203      행복이 있는 동물병원          서울특별시 중랑구 신내동 405번지 5호     02-433-3387
# 3   20131119      닥터 아이펫 동물병원          서울특별시 중랑구 상봉동 99번지 10호       2208-0329
# 4   20000721           신내동물병원  서울특별시 중랑구 중화동 11번지 36호 삼일시티빌 1층      3422-0001
# 5   20060104           주연동물병원         서울특별시 중랑구 면목동 353번지 25호       2207-9931
# 6   20021203     24시 동물응급의료센터         서울특별시 중랑구 중화동 207번지 지하1층      2208-7233
# 7   19970317          홍상희동물병원          서울특별시 중랑구 묵동 239번지 76호        974-0339
# 8   20101027  한국동물메디컬센터(KAMC)      서울특별시 중랑구 면목동 119번지 10호 12층      2208-6788
# 9   20050325          쥬라기동물병원  서울특별시 중랑구 신내동 646번지 금강리빙스텔 119호      3421-7588
# 10  20160421           보담동물병원          서울특별시 중랑구 면목동 17번지 31호     02-494-7775
# ...

# %%
jungnang_hospital['사업장소재지(구)'] = '중랑구'
jungnang_hospital = jungnang_hospital[['신고일자','업소명','사업장소재지(구)','사업장소재지(지번)','전화번호']]
jungnang_hospital
# Out:
#         신고일자              업소명 사업장소재지(구)                        사업장소재지(지번)  \
# 0   19911130           태능동물병원       중랑구         서울특별시 중랑구 묵동 175번지 2호 3층
# 1   20141107       도그플러스 동물병원       중랑구      서울특별시 중랑구 신내동 645번지 홈플러스 2층
# 2   20141203      행복이 있는 동물병원       중랑구          서울특별시 중랑구 신내동 405번지 5호
# 3   20131119      닥터 아이펫 동물병원       중랑구          서울특별시 중랑구 상봉동 99번지 10호
# 4   20000721           신내동물병원       중랑구  서울특별시 중랑구 중화동 11번지 36호 삼일시티빌 1층
# 5   20060104           주연동물병원       중랑구         서울특별시 중랑구 면목동 353번지 25호
# 6   20021203     24시 동물응급의료센터       중랑구         서울특별시 중랑구 중화동 207번지 지하1층
# 7   19970317          홍상희동물병원       중랑구          서울특별시 중랑구 묵동 239번지 76호
# 8   20101027  한국동물메디컬센터(KAMC)       중랑구      서울특별시 중랑구 면목동 119번지 10호 12층
# 9   20050325          쥬라기동물병원       중랑구  서울특별시 중랑구 신내동 646번지 금강리빙스텔 119호
# 10  20160421           보담동물병원       중랑구          서울특별시 중랑구 면목동 17번지 31호
# 11  20170518       한국동물영상의학센터       중랑구          서울특별시 중랑구 중화동 207번지 6호
# ...

# %%
outer_join = pd.merge(seocho_hospital, gangnam_hospital,how='outer')
outer_join
# Out:
#          신고일자              업소명 사업장소재지(구)  \
# 0    20160725  VIP동물의료센터 서초동작점       서초구
# 1    20081121           리즈동물병원       서초구
# 2    20051230          다니엘동물병원       서초구
# 3    20190812    에이비씨(ABC)동물병원       서초구
# 4    20190718      V+care 동물병원       서초구
# 5    20000221          레스펫동물병원       서초구
# 6    20040414          이상록동물병원       서초구
# 7    20040308           우면동물병원       서초구
# 8    20011217         방배한강동물병원       서초구
# 9    19980112           서초동물병원       서초구
# 10   19970117          남서울동물병원       서초구
# 11   20000711          라파엘동물병원       서초구
# 12   19990504        신반포종합동물병원       서초구
# 13   20030113            수동물병원       서초구
# 14   20040316          사랑의동물병원       서초구
# 15   20031201         메디펫 동물병원       서초구
# 16   20040322           한 동물병원       서초구
# 17   20060906           서래동물병원       서초구
# 18   20060221           교대동물병원       서초구
# 19   20091023         두리종합동물병원       서초구
# 20   19990306           서이동물병원       서초구
# 21   20030204           내방동물병원       서초구
# ...

# %%
outer_join = pd.merge(outer_join, gangdong_hospital,how='outer')

# %%
outer_join = pd.merge(outer_join, gangbook_hospital,how='outer')

# %%
outer_join.count()
# Out:
# 신고일자          197
# 업소명           197
# 사업장소재지(구)     197
# 사업장소재지(지번)    197
# 전화번호          188
# dtype: int64

# %%
outer_join = pd.merge(outer_join, gangseo_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          244
# 업소명           244
# 사업장소재지(구)     244
# 사업장소재지(지번)    244
# 전화번호          233
# dtype: int64

# %%
outer_join = pd.merge(outer_join, gwanak_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          273
# 업소명           273
# 사업장소재지(구)     273
# 사업장소재지(지번)    273
# 전화번호          262
# dtype: int64

# %%
outer_join = pd.merge(outer_join, gwangjin_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          310
# 업소명           310
# 사업장소재지(구)     310
# 사업장소재지(지번)    310
# 전화번호          299
# dtype: int64

# %%
outer_join = pd.merge(outer_join, guro_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          332
# 업소명           332
# 사업장소재지(구)     332
# 사업장소재지(지번)    332
# 전화번호          320
# dtype: int64

# %%
outer_join = pd.merge(outer_join, geumcheon_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          347
# 업소명           347
# 사업장소재지(구)     347
# 사업장소재지(지번)    347
# 전화번호          332
# dtype: int64

# %%
outer_join = pd.merge(outer_join, nowon_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          386
# 업소명           386
# 사업장소재지(구)     386
# 사업장소재지(지번)    386
# 전화번호          370
# dtype: int64

# %%
outer_join = pd.merge(outer_join, dobong_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          410
# 업소명           410
# 사업장소재지(구)     410
# 사업장소재지(지번)    410
# 전화번호          394
# dtype: int64

# %%
outer_join = pd.merge(outer_join, dongdaemun_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          436
# 업소명           436
# 사업장소재지(구)     436
# 사업장소재지(지번)    436
# 전화번호          420
# dtype: int64

# %%
outer_join = pd.merge(outer_join, dongjak_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          459
# 업소명           459
# 사업장소재지(구)     459
# 사업장소재지(지번)    459
# 전화번호          443
# dtype: int64

# %%
outer_join = pd.merge(outer_join, mapo_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          505
# 업소명           505
# 사업장소재지(구)     505
# 사업장소재지(지번)    505
# 전화번호          489
# dtype: int64

# %%
outer_join = pd.merge(outer_join, seodaemun_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          529
# 업소명           529
# 사업장소재지(구)     529
# 사업장소재지(지번)    529
# 전화번호          513
# dtype: int64

# %%
outer_join = pd.merge(outer_join, seongdong_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          563
# 업소명           563
# 사업장소재지(구)     563
# 사업장소재지(지번)    563
# 전화번호          546
# dtype: int64

# %%
outer_join = pd.merge(outer_join, seongbuk_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          595
# 업소명           595
# 사업장소재지(구)     595
# 사업장소재지(지번)    595
# 전화번호          576
# dtype: int64

# %%
outer_join = pd.merge(outer_join, songpa_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          658
# 업소명           658
# 사업장소재지(구)     658
# 사업장소재지(지번)    658
# 전화번호          637
# dtype: int64

# %%
outer_join = pd.merge(outer_join, yangchun_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          702
# 업소명           702
# 사업장소재지(구)     702
# 사업장소재지(지번)    702
# 전화번호          681
# dtype: int64

# %%
outer_join = pd.merge(outer_join, yeongdeungpo_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          733
# 업소명           733
# 사업장소재지(구)     733
# 사업장소재지(지번)    733
# 전화번호          712
# dtype: int64

# %%
outer_join = pd.merge(outer_join, yongsan_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          762
# 업소명           762
# 사업장소재지(구)     762
# 사업장소재지(지번)    762
# 전화번호          741
# dtype: int64

# %%
outer_join = pd.merge(outer_join, eunpyeong_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          799
# 업소명           799
# 사업장소재지(구)     799
# 사업장소재지(지번)    799
# 전화번호          778
# dtype: int64

# %%
outer_join = pd.merge(outer_join, jongno_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          808
# 업소명           808
# 사업장소재지(구)     808
# 사업장소재지(지번)    808
# 전화번호          785
# dtype: int64

# %%
outer_join = pd.merge(outer_join, junggu_hospital,how='outer')
outer_join.count()
# Out:
# 신고일자          827
# 업소명           827
# 사업장소재지(구)     827
# 사업장소재지(지번)    827
# 전화번호          804
# dtype: int64

# %%
seoul_hospital = pd.merge(outer_join, jungnang_hospital,how='outer')
seoul_hospital.count()
# Out:
# 신고일자          857
# 업소명           857
# 사업장소재지(구)     857
# 사업장소재지(지번)    857
# 전화번호          833
# dtype: int64

# %%
seoul_hospital[seoul_hospital['사업장소재지(구)']=='강남구'].count()
# Out:
# 신고일자          77
# 업소명           77
# 사업장소재지(구)     77
# 사업장소재지(지번)    77
# 전화번호          73
# dtype: int64

# %%
seoul_hospital['병원개수'] =''

# %%
hospital_result = seoul_hospital.groupby('사업장소재지(구)').count()
hospital_result = hospital_result.reset_index()
hospital_result.head()
# Out:
#   사업장소재지(구)  신고일자  업소명  사업장소재지(지번)  전화번호  병원개수
# 0       강남구    77   77          77    73    77
# 1       강동구    45   45          45    43    45
# 2       강북구    24   24          24    24    24
# 3       강서구    47   47          47    45    47
# 4       관악구    29   29          29    29    29

# %%
hospital_result[['사업장소재지(구)','병원개수']]
# Out:
#    사업장소재지(구)  병원개수
# 0        강남구    77
# 1        강동구    45
# 2        강북구    24
# 3        강서구    47
# 4        관악구    29
# 5        광진구    37
# 6        구로구    22
# 7        금천구    15
# 8        노원구    39
# 9        도봉구    24
# 10      동대문구    26
# 11       동작구    23
# 12       마포구    46
# 13      서대문구    24
# 14       서초구    51
# 15       성동구    34
# 16       성북구    32
# 17       송파구    63
# 18       양천구    44
# 19      영등포구    31
# 20       용산구    29
# 21       은평구    37
# 22       종로구     9
# 23        중구    19
# 24       중랑구    30

# %%
hospital_result['병원개수'].sum()
# Out:
# 857

# %%
hospital_result['병원개수'].mean()
# Out:
# 34.28

# %%
# 구별 동물병원 개수 /평균
hospital_result['구별 병원 비율'] = round(hospital_result['병원개수']/(hospital_result['병원개수'].mean()),2)
hospital_result['전체평균갯수'] = hospital_result['병원개수'].mean()

# %%
hospital_rate=hospital_result[['사업장소재지(구)','병원개수','전체평균갯수']]
hospital_rate
# Out:
#    사업장소재지(구)  병원개수  전체평균갯수
# 0        강남구    77   34.28
# 1        강동구    45   34.28
# 2        강북구    24   34.28
# 3        강서구    47   34.28
# 4        관악구    29   34.28
# 5        광진구    37   34.28
# 6        구로구    22   34.28
# 7        금천구    15   34.28
# 8        노원구    39   34.28
# 9        도봉구    24   34.28
# 10      동대문구    26   34.28
# 11       동작구    23   34.28
# 12       마포구    46   34.28
# 13      서대문구    24   34.28
# 14       서초구    51   34.28
# 15       성동구    34   34.28
# 16       성북구    32   34.28
# 17       송파구    63   34.28
# 18       양천구    44   34.28
# 19      영등포구    31   34.28
# 20       용산구    29   34.28
# 21       은평구    37   34.28
# 22       종로구     9   34.28
# 23        중구    19   34.28
# 24       중랑구    30   34.28

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import re
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rc('font', family='Malgun Gothic')

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() =='Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unkonwn systme...')

# %%
gu = '은평구'
hospital_per_gu = hospital_rate[hospital_rate['사업장소재지(구)'].str.contains(gu)]
hospital_per_gu.columns = ['지역',gu,'전체평균갯수']
hospital_per_gu
# Out:
#      지역  은평구  전체평균갯수
# 21  은평구   37   34.28

# %%
print('본인이 살고 있는 "구"를 선택해주세요.', gu)
# Out:
# 본인이 살고 있는 "구"를 선택해주세요. 은평구

# %%
hospital_rate.to_csv('../data/animal/hospital.csv', sep=',', encoding = 'utf-8')

# %%
plt.figure(figsize=(8,8))
plt.title("본인이 살고있는 지역의 동물 병원 갯수와 평균병원수")
sns.barplot(data=hospital_per_gu)

# %%
for gu in hospital_rate['사업장소재지(구)']:
    hospital_per_gu=hospital_rate[hospital_rate['사업장소재지(구)'].str.contains(gu)]
    hospital_per_gu.columns = ['지역',gu,'전체평균갯수']
    plt.figure(figsize=(8,8))
    plt.title("구별 동물 병원수와 서울시 평균 동물 병원수")
    sns.barplot(data=hospital_per_gu)
    plt.ylim(0, 80)
    plt.savefig('../img/' + gu + '.png', bbox_inches='tight')
